# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

def Data(entry, Type=1):
    entry_dt = pd.to_datetime(entry, dayfirst=True)
    lower = entry_dt - pd.Timedelta(weeks=1)
    upper = entry_dt + pd.DateOffset(months=1)
    print("Filter range:", lower, "to", upper)

    if Type == 1:
        df = pd.read_csv(r"C:\Users\PC\Downloads\output\EURUSD_ticks.csv\EURUSD_ticks.csv",
                         parse_dates=['Timestamp'])
        # If timestamps are tz-aware, drop tz info.
        if df['Timestamp'].dt.tz is not None:
            df['Local time'] = df['Timestamp'].dt.tz_localize(None)
        else:
            df['Local time'] = df['Timestamp']
        print("CSV min:", df['Local time'].min(), "max:", df['Local time'].max())
        df[['Ask', 'Bid']] = df[['Ask', 'Bid']].apply(pd.to_numeric, errors='coerce')
        df['Mid'] = (df['Ask'] + df['Bid']) / 2
        # Filter using the naive timestamps.
        df = df[(df['Local time'] >= lower) & (df['Local time'] <= upper)]
        return df[['Timestamp', 'Local time', 'Ask', 'Bid', 'Mid']]

    elif Type == 2:
        engine = create_engine('postgresql://postgres:Monarch@localhost:5432/PallasDB')
        # Force cast to naive timestamp in SQL.
        query = f"""
            SELECT timestamp::timestamp AS timestamp, ask, bid
            FROM "EURUSD_tickdata"
            WHERE timestamp BETWEEN 
                  '{lower.strftime('%Y-%m-%d %H:%M:%S')}' AND '{upper.strftime('%Y-%m-%d %H:%M:%S')}'
        """
        df = pd.read_sql(query, engine)
        print("DB min:", df['timestamp'].min(), "max:", df['timestamp'].max())
        df = df.rename(columns={'timestamp': 'Timestamp', 'ask': 'Ask', 'bid': 'Bid'})
        df['Local time'] = df['Timestamp']
        df['Mid'] = (df['Ask'] + df['Bid']) / 2
        return df[['Timestamp', 'Local time', 'Ask', 'Bid', 'Mid']]

# %%
def calculate_return_and_mdd(entry_time, entry_price, trade_type, exit_price, exit_mode, data, sl, risk, min_wait=pd.Timedelta(minutes=3)):
    # Filter data forward from entry_time
    df = data[data['Local time'] >= entry_time].copy()
    if df.empty:
        print("No data after entry.")
        return None, None, None

    if exit_mode.upper() in ["TP", "SL"]:
        if trade_type.lower() == "long":
            # For a long trade, TP means Bid >= exit_price, SL means Bid <= exit_price
            cond = df['Bid'] >= exit_price if exit_mode.upper() == "TP" else df['Bid'] <= exit_price
            exit_rows = df[cond]
            if exit_rows.empty:
                print("No exit tick found for", exit_mode)
                return None, None, None

            exit_time = exit_rows.iloc[0]['Local time']
            exit_price_actual = exit_rows.iloc[0]['Bid']

            # Compute MDD using all Bid prices up to exit
            prices = df[df['Local time'] <= exit_time]['Bid']
            mdd = ((prices - prices.cummax()) / prices.cummax()).min()

            # Return in R
            ret = ((exit_price_actual - entry_price) / (entry_price - sl)) * risk

        elif trade_type.lower() == "short":
            # For a short trade, TP means Ask <= exit_price, SL means Ask >= exit_price
            cond = df['Ask'] <= exit_price if exit_mode.upper() == "TP" else df['Ask'] >= exit_price
            exit_rows = df[cond]
            if exit_rows.empty:
                print("No exit tick found for", exit_mode)
                return None, None, None

            exit_time = exit_rows.iloc[0]['Local time']
            exit_price_actual = exit_rows.iloc[0]['Ask']

            # Compute MDD using all Ask prices up to exit
            prices = df[df['Local time'] <= exit_time]['Ask']
            mdd = ((prices.cummin() - prices) / prices.cummin()).min()

            # Return in R
            ret = ((entry_price - exit_price_actual) / (sl - entry_price)) * risk

    elif exit_mode.upper() == "PARTIAL":
        # We use a simple SMA-based reversal trigger plus a waiting period
        ma_window = 10
        if trade_type.lower() == "long":
            df['SMA'] = df['Bid'].rolling(window=ma_window, min_periods=1).mean()
            # Reversal when SMA crosses from above to below exit_price
            cond_T1 = (df['SMA'].shift(1) > exit_price) & (df['SMA'] <= exit_price)
            candidates = df[cond_T1]
            if candidates.empty:
                print("No reversal found for partial exit (long).")
                return None, None, None

            T1 = candidates.iloc[0]['Local time']

            # Make sure we find the first TP crossing *after* T1
            tp_rows = df[(df['Bid'] >= exit_price) & (df['Local time'] >= T1)]
            if tp_rows.empty:
                print("No TP candidate found after T1 for partial exit (long).")
                return None, None, None

            T_tp = tp_rows.iloc[0]['Local time']

            # 20% of the time from entry to T_tp (but at least min_wait)
            waiting_period = pd.Timedelta(seconds=(T_tp - entry_time).total_seconds() * 0.2)
            waiting_period = max(waiting_period, min_wait)
            threshold_time = T1 + waiting_period

            # After waiting, pick the row nearest to exit_price
            later_df = df[df['Local time'] >= threshold_time]
            if not later_df.empty:
                idx = (later_df['Bid'] - exit_price).abs().idxmin()
                exit_row = later_df.loc[idx]
            else:
                exit_row = candidates.iloc[0]  # fallback if no data after threshold

            exit_time = exit_row['Local time']
            exit_price_actual = exit_row['Bid']

            prices = df[df['Local time'] <= exit_time]['Bid']
            mdd = ((prices - prices.cummax()) / prices.cummax()).min()
            ret = ((exit_price_actual - entry_price) / (entry_price - sl)) * risk

        elif trade_type.lower() == "short":
            df['SMA'] = df['Ask'].rolling(window=ma_window, min_periods=1).mean()
            # Reversal when SMA crosses from below to above exit_price
            cond_T1 = (df['SMA'].shift(1) < exit_price) & (df['SMA'] >= exit_price)
            candidates = df[cond_T1]
            if candidates.empty:
                print("No reversal found for partial exit (short).")
                return None, None, None

            T1 = candidates.iloc[0]['Local time']

            # Make sure we find the first TP crossing *after* T1
            tp_rows = df[(df['Ask'] <= exit_price) & (df['Local time'] >= T1)]
            if tp_rows.empty:
                print("No TP candidate found after T1 for partial exit (short).")
                return None, None, None

            T_tp = tp_rows.iloc[0]['Local time']

            # 20% of the time from entry to T_tp (but at least min_wait)
            waiting_period = pd.Timedelta(seconds=(T_tp - entry_time).total_seconds() * 0.2)
            waiting_period = max(waiting_period, min_wait)
            threshold_time = T1 + waiting_period

            later_df = df[df['Local time'] >= threshold_time]
            if not later_df.empty:
                idx = (later_df['Ask'] - exit_price).abs().idxmin()
                exit_row = later_df.loc[idx]
            else:
                exit_row = candidates.iloc[0]

            exit_time = exit_row['Local time']
            exit_price_actual = exit_row['Ask']

            prices = df[df['Local time'] <= exit_time]['Ask']
            mdd = ((prices.cummin() - prices) / prices.cummin()).min()
            ret = ((entry_price - exit_price_actual) / (sl - entry_price)) * risk

    else:
        print("Invalid exit mode.")
        return None, None, None

    # Return in the same format as original: ret, MDD%, exit_time
    return ret, mdd * 100, exit_time


def find_and_plot(trade_date_str, trade_type, entry_price, exit_price, sl, risk, exit_mode, data, returnSeen, mode=1):
    # Ensure data is time-sorted
    data = data.sort_values('Local time').reset_index(drop=True)

    approx_time = pd.to_datetime(trade_date_str, errors='coerce')
    price_col = 'Ask' if trade_type.lower() == 'long' else 'Bid'

    # Search ±12h around approximate time
    window_df = data[
        (data['Local time'] >= approx_time - pd.Timedelta(hours=12)) &
        (data['Local time'] <= approx_time + pd.Timedelta(hours=12))
    ].copy()
    if window_df.empty:
        print("No data in ±12h window.")
        return 0,0,0,0,0,0,0

    # Find row whose price is either an exact match (within tol)
    # or else the minimal price difference
    window_df['time_diff'] = (window_df['Local time'] - approx_time).abs()
    window_df['price_diff'] = (window_df[price_col] - entry_price).abs()
    tol = 1e-5
    exact_matches = window_df[window_df['price_diff'] <= tol]
    if not exact_matches.empty:
        pick_idx = exact_matches['time_diff'].idxmin()
    else:
        pick_idx = window_df['price_diff'].idxmin()

    matched_row = window_df.loc[pick_idx]
    matched_time = matched_row['Local time']
    matched_price = matched_row[price_col]

    print(f"Approx Time: {approx_time}, Price: {entry_price}")
    print(f"Matched Time: {matched_time}, Price: {matched_price}")

    # Calculate returns from that matched entry
    ret, mdd, exit_time = calculate_return_and_mdd(
        matched_time, matched_price, trade_type, exit_price, exit_mode, data, sl, risk
    )
    if ret is None:
        return 0,0,0,0,0,0,0

    # Compute drawdown stats in that trade window
    trade_df = data[(data['Local time'] >= matched_time) & (data['Local time'] <= exit_time)]
    if trade_df.empty:
        print("Not enough trade data for Ulcer Index.")
        return ret, mdd, exit_time, 0, 0, 0, 0

    if trade_type.lower() == "long":
        dd = (trade_df['Bid'] - trade_df['Bid'].cummax()) / trade_df['Bid'].cummax() * 100
    else:
        dd = (trade_df['Ask'].cummin() - trade_df['Ask']) / trade_df['Ask'].cummin() * 100

    UI = np.sqrt((dd**2).mean())
    UPI = (ret - risk) / UI if UI != 0 else np.inf
    CALMAR = (ret - risk) / abs(mdd) if abs(mdd) > 1e-8 else np.nan

    print(f"Return True: {returnSeen:.2f}")
    print(f"Return: {ret:.2f}% | MDD: {mdd:.2f}% | CALMAR: {CALMAR:.2f} | UI: {UI:.2f} | UPI: {UPI:.2f}")
    RV = False if abs(returnSeen - ret) > 0.02 else True
    print(f"Return Verification: {RV}")

    if mode == 1:
        # Plot from approx_time-12h to exit_time+12h
        plot_start = approx_time - pd.Timedelta(hours=12)
        plot_end   = exit_time + pd.Timedelta(hours=12)
        extended_window = data[(data['Local time'] >= plot_start) & (data['Local time'] <= plot_end)]

        print(f"Plotting from {plot_start} to {plot_end}")

        plt.figure(figsize=(20, 10))
        plt.plot(extended_window['Local time'], extended_window['Ask'], color='linen', label='Ask Price', linewidth=0.75, alpha=0.75)
        plt.plot(extended_window['Local time'], extended_window['Bid'], color='bisque', label='Bid Price', linewidth=0.75, alpha=0.75)

        EntrySignal = "^" if trade_type.lower() == "long" else "v"
        ExitSignal  = "v" if trade_type.lower() == "long" else "^"

        plt.scatter(matched_time, matched_price, marker=EntrySignal, color="lime", label="Matched Entry", s=150)
        plt.scatter(approx_time, entry_price, marker='x', color="aqua", label="Approx Entry", s=50)

        if ret is not None:
            plt.scatter(exit_time, exit_price, marker=ExitSignal, color="red", label="Exit Tick", s=150)

        plt.title(f"Price Movement from {plot_start} to {plot_end}")
        plt.xlabel('Time (Local)')
        plt.ylabel('Price')
        plt.legend()
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

    return matched_time, exit_time, ret, mdd, CALMAR, UI, UPI

# %%
trades = pd.read_excel(r"C:\Users\PC\Downloads\Classeur de Trade V2.xlsm", sheet_name=2)
trades.drop(trades.index[-1], inplace=True)
trades.columns
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python313\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# Index(['Date', 'Asset', 'Long Short', 'Capital', 'Capital Auto', 'Kpi',
#        'Risque ', 'Entrée', 'TP ', 'TP en %', 'SL', 'SL en %', 'Ratio',
#        'StateResult', 'Profit Généré', 'Perte Généré', 'P&L in R', 'Hedge',
#        'Break Even', 'Management', '% Mana sur Cotation', '% Entry -> TP',
#        '% SL -> Entry', 'Explication', 'Key-Word errors',
#        'Photo de correction', 'Photo fin de Position', 'Capital Cumulé',
#        'Ajout Capital', 'Sortie de Capital', 'Evolution du capital',
#        '% Cumulated', 'Type', 'Situation', 'TM', 'Analyse', 'Entree Type',
#        'TP Type', 'SL Type', 'Mana', 'Pilier D'analyse', 'Outil Externe',
#        'Ressenti', 'Instinct', 'Mood', 'Base cumule', 'Peak', 'DD', 'j week',
#        'week', 'Année', 'Mois Num', 'j mois'],
#       dtype='object')

# %%
trades.columns = trades.columns.str.strip()
columns = ["Entry_Time", "Entry_Price", "Exit_Time", "Exit_Price", "TP", "SL", "Risk", "State", "Return", "MDD", "CALMAR", "UI", "UPI"]
df = pd.DataFrame(columns=columns)
for i in range(len(trades)):
    if trades["Asset"][i].lower() == "eurusd":
        # Parameters:
        trade_date = trades["Date"][i]
        trade_type = trades["Long Short"][i]
        entry_price = trades["Entrée"][i]

        be_value = trades["Break Even"][i]
        be_str = be_value.lower() if pd.notnull(be_value) and isinstance(be_value, str) else ""

        exit_price = (
            trades["TP"][i]
            if trades["StateResult"][i].lower() == "win"
            else (
                trades["Management"][i]
                if trades["StateResult"][i].lower() == "lose" and be_str == "be" and trades["Management"][i] >= trades["Entrée"][i]
                else (
                    trades["Entrée"][i]
                    if trades["StateResult"][i].lower() == "lose" and be_str == "be" and trades["Management"][i] < trades["Entrée"][i]
                    else trades["SL"][i]
                )
            )
        )

        tp = trades["TP"][i]
        sl = trades["SL"][i]
        risk = trades["Risque"][i]
        exit_mode = "TP" if trades["StateResult"][i].lower() == "win" else "SL" if trades["StateResult"][i].lower() == "lose" and trades["P&L in R"][i] == -1 else "PARTIAL"
        data = Data(trade_date, 2)
        print(f"Case: {exit_mode}")
        ENTRY_T, EXIT_T, RET, MDD, CALMAR, UI, UPI = find_and_plot(trade_date, trade_type, entry_price, exit_price, sl, risk, exit_mode, data, trades["Evolution du capital"][i], 0)
        if (RET + MDD + CALMAR + UI + UPI) == 0:
            pass
        print("*~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*")
        df.loc[len(df)] = {
            "Entry_Time": ENTRY_T,
            "Entry_Price": ENTRY_T,
            "Exit_Time": EXIT_T,
            "Exit_Price": ENTRY_T,
            "TP": tp,
            "SL": sl,
            "Risk": risk,
            "State": exit_mode,
            "Return": RET,
            "MDD": MDD,
            "CALMAR": CALMAR,
            "UI": UI,
            "UPI": UPI
        }
# Out:
# Filter range: 2025-02-20 10:12:00 to 2025-03-27 10:12:00
# DB min: 2025-02-20 10:12:00.137000 max: 2025-02-28 01:59:59.992000
# Case: PARTIAL
# Approx Time: 2025-02-27 10:12:00, Price: 1.04793
# Matched Time: 2025-02-27 10:12:13.086000, Price: 1.04793
# Return True: 0.00
# Return: 0.00% | MDD: -0.03% | CALMAR: -0.30 | UI: 0.02 | UPI: -0.52
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-02-19 12:08:00 to 2025-03-26 12:08:00
# DB min: 2025-02-19 12:08:00.114000 max: 2025-02-28 01:59:59.992000
# Case: PARTIAL
# Approx Time: 2025-02-26 12:08:00, Price: 1.0494
# Matched Time: 2025-02-26 12:21:01.297000, Price: 1.04941
# Return True: 0.00
# Return: 0.00% | MDD: -0.04% | CALMAR: -0.03 | UI: 0.01 | UPI: -0.06
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-02-18 00:00:00 to 2025-03-25 00:00:00
# DB min: 2025-02-18 00:00:00.146000 max: 2025-02-28 01:59:59.992000
# Case: PARTIAL
# Approx Time: 2025-02-25 00:00:00, Price: 1.05177
# Matched Time: 2025-02-24 19:27:29.154000, Price: 1.04856
# Return True: 0.01
# Return: -0.01% | MDD: -0.60% | CALMAR: -0.03 | UI: 0.31 | UPI: -0.06
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-02-11 12:07:00 to 2025-03-18 12:07:00
# DB min: 2025-02-11 12:07:08.312000 max: 2025-02-28 01:59:59.992000
# Case: PARTIAL
# Approx Time: 2025-02-18 12:07:00, Price: 1.04663
# Matched Time: 2025-02-18 13:07:12.323000, Price: 1.04663
# Return True: 0.08
# Return: 0.00% | MDD: -0.63% | CALMAR: -0.02 | UI: 0.24 | UPI: -0.04
# Return Verification: False
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-02-10 16:37:00 to 2025-03-17 16:37:00
# DB min: 2025-02-10 16:37:00.872000 max: 2025-02-28 01:59:59.992000
# Case: TP
# Approx Time: 2025-02-17 16:37:00, Price: 1.04774
# Matched Time: 2025-02-17 16:52:34.842000, Price: 1.04774
# Return True: 0.02
# Return: 0.02% | MDD: -0.06% | CALMAR: 0.30 | UI: 0.03 | UPI: 0.61
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-02-10 15:55:00 to 2025-03-17 15:55:00
# DB min: 2025-02-10 15:55:00.198000 max: 2025-02-28 01:59:59.992000
# Case: PARTIAL
# Approx Time: 2025-02-17 15:55:00, Price: 1.04747
# Matched Time: 2025-02-17 15:40:45.516000, Price: 1.04747
# Return True: 0.01
# Return: 0.01% | MDD: -0.02% | CALMAR: 0.00 | UI: 0.01 | UPI: 0.00
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-01-30 10:10:00 to 2025-03-06 10:10:00
# DB min: 2025-01-30 10:10:00.836000 max: 2025-02-28 01:59:59.992000
# Case: PARTIAL
# Approx Time: 2025-02-06 10:10:00, Price: 1.03575
# Matched Time: 2025-02-06 10:22:31.555000, Price: 1.03575
# Return True: 0.02
# Return: 0.02% | MDD: -0.04% | CALMAR: 0.33 | UI: 0.01 | UPI: 1.06
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-01-30 09:20:00 to 2025-03-06 09:20:00
# DB min: 2025-01-30 09:20:00.025000 max: 2025-02-28 01:59:59.992000
# Case: PARTIAL
# Approx Time: 2025-02-06 09:20:00, Price: 1.03601
# Matched Time: 2025-02-06 09:32:44.534000, Price: 1.03602
# Return True: -0.00
# Return: -0.01% | MDD: -0.12% | CALMAR: -0.12 | UI: 0.06 | UPI: -0.25
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-01-27 12:31:00 to 2025-03-03 12:31:00
# DB min: 2025-01-27 12:31:00.163000 max: 2025-02-28 01:59:59.992000
# Case: PARTIAL
# Approx Time: 2025-02-03 12:31:00, Price: 1.02376
# Matched Time: 2025-02-03 12:31:40.638000, Price: 1.02376
# Return True: 0.00
# Return: 0.00% | MDD: -0.18% | CALMAR: 0.02 | UI: 0.05 | UPI: 0.07
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-01-20 16:40:00 to 2025-02-27 16:40:00
# DB min: 2025-01-20 16:40:00.417000 max: 2025-02-27 16:39:58.772000
# Case: SL
# Approx Time: 2025-01-27 16:40:00, Price: 1.04921
# Matched Time: 2025-01-27 17:39:27.172000, Price: 1.04921
# Return True: -0.00
# Return: -0.00% | MDD: -0.09% | CALMAR: -0.04 | UI: 0.05 | UPI: -0.08
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-01-20 14:00:00 to 2025-02-27 14:00:00
# DB min: 2025-01-20 14:00:00.077000 max: 2025-02-27 13:59:59.088000
# Case: TP
# Approx Time: 2025-01-27 14:00:00, Price: 1.05185
# Matched Time: 2025-01-27 14:00:26.814000, Price: 1.05185
# No exit tick found for TP
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-01-02 15:38:00 to 2025-02-09 15:38:00
# DB min: 2025-01-02 15:38:00.078000 max: 2025-02-07 22:59:59.586000
# Case: PARTIAL
# Approx Time: 2025-01-09 15:38:00, Price: 1.0312
# Matched Time: 2025-01-09 15:38:36.604000, Price: 1.03119
# Return True: 0.01
# Return: -0.00% | MDD: -1.74% | CALMAR: -0.00 | UI: 0.85 | UPI: -0.01
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2025-01-02 15:12:00 to 2025-02-09 15:12:00
# DB min: 2025-01-02 15:12:00.004000 max: 2025-02-07 22:59:59.586000
# Case: TP
# Approx Time: 2025-01-09 15:12:00, Price: 1.03145
# Matched Time: 2025-01-09 15:17:26.385000, Price: 1.03145
# Return True: 0.05
# Return: 0.05% | MDD: -0.07% | CALMAR: 0.62 | UI: 0.03 | UPI: 1.44
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-12-09 12:00:00 to 2025-01-16 12:00:00
# DB min: 2024-12-09 12:00:00.112000 max: 2025-01-16 11:59:59.959000
# Case: PARTIAL
# Approx Time: 2024-12-16 12:00:00, Price: 1.04617
# Matched Time: 2024-12-16 15:51:26.394000, Price: 1.04748
# Return True: 0.00
# Return: -0.01% | MDD: -1.82% | CALMAR: -0.01 | UI: 1.13 | UPI: -0.02
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-10-15 12:27:00 to 2024-11-22 12:27:00
# DB min: 2024-10-15 12:27:00.414000 max: 2024-11-22 12:26:59.956000
# Case: PARTIAL
# Approx Time: 2024-10-22 12:27:00, Price: 1.08273
# Matched Time: 2024-10-22 12:35:49.614000, Price: 1.08273
# Return True: 0.01
# Return: 0.00% | MDD: -0.04% | CALMAR: -0.23 | UI: 0.02 | UPI: -0.45
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-10-15 12:20:00 to 2024-11-22 12:20:00
# DB min: 2024-10-15 12:20:03.323000 max: 2024-11-22 12:19:58.702000
# Case: PARTIAL
# Approx Time: 2024-10-22 12:20:00, Price: 1.08229
# Matched Time: 2024-10-22 12:21:13.029000, Price: 1.08229
# Return True: -0.00
# Return: -0.00% | MDD: -0.04% | CALMAR: -0.30 | UI: 0.02 | UPI: -0.56
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-08-26 14:00:00 to 2024-10-02 14:00:00
# DB min: 2024-08-26 14:00:00.080000 max: 2024-10-02 13:59:59.872000
# Case: PARTIAL
# Approx Time: 2024-09-02 14:00:00, Price: 1.10601
# Matched Time: 2024-09-02 13:59:54.873000, Price: 1.106
# Return True: 0.03
# Return: 0.03% | MDD: -0.05% | CALMAR: 0.43 | UI: 0.02 | UPI: 1.01
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-08-12 17:09:00 to 2024-09-19 17:09:00
# DB min: 2024-08-12 17:09:01.381000 max: 2024-09-19 17:08:59.827000
# Case: TP
# Approx Time: 2024-08-19 17:09:00, Price: 1.10648
# Matched Time: 2024-08-19 17:09:15.795000, Price: 1.10648
# Return True: 0.16
# Return: 0.16% | MDD: -0.01% | CALMAR: 9.43 | UI: 0.00 | UPI: 36.45
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-08-12 17:04:00 to 2024-09-19 17:04:00
# DB min: 2024-08-12 17:04:01.201000 max: 2024-09-19 17:03:59.702000
# Case: PARTIAL
# Approx Time: 2024-08-19 17:04:00, Price: 1.10635
# Matched Time: 2024-08-19 17:03:07.685000, Price: 1.10634
# Return True: 0.10
# Return: 0.11% | MDD: -0.03% | CALMAR: 1.87 | UI: 0.01 | UPI: 5.67
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-06-06 14:00:00 to 2024-07-13 14:00:00
# DB min: 2024-06-06 14:00:00.163000 max: 2024-07-12 22:59:59.398000
# Case: TP
# Approx Time: 2024-06-13 14:00:00, Price: 1.07841
# Matched Time: 2024-06-13 13:59:09.142000, Price: 1.07842
# Return True: 0.04
# Return: 0.04% | MDD: -0.08% | CALMAR: 0.40 | UI: 0.01 | UPI: 2.62
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-05-31 10:19:02 to 2024-07-07 10:19:02
# DB min: 2024-05-31 10:19:07.638000 max: 2024-07-05 22:59:59.470000
# Case: TP
# Approx Time: 2024-06-07 10:19:02, Price: 1.08957
# Matched Time: 2024-06-07 09:56:40.969000, Price: 1.08956
# Return True: 0.02
# Return: nan% | MDD: -0.04% | CALMAR: nan | UI: 0.02 | UPI: nan
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-05-31 10:19:00 to 2024-07-07 10:19:00
# DB min: 2024-05-31 10:19:00.177000 max: 2024-07-05 22:59:59.470000
# Case: TP
# Approx Time: 2024-06-07 10:19:00, Price: 1.0894
# Matched Time: 2024-06-07 09:58:23.526000, Price: 1.08939
# Return True: 0.01
# Return: nan% | MDD: -0.00% | CALMAR: nan | UI: 0.00 | UPI: nan
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-05-30 13:33:00 to 2024-07-06 13:33:00
# DB min: 2024-05-30 13:33:10.630000 max: 2024-07-05 22:59:59.470000
# Case: PARTIAL
# Approx Time: 2024-06-06 13:33:00, Price: 1.08825
# Matched Time: 2024-06-06 14:15:52.359000, Price: 1.08824
# Return True: -0.00
# Return: -0.01% | MDD: -0.21% | CALMAR: -0.10 | UI: 0.09 | UPI: -0.21
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-18 12:00:00 to 2024-05-25 12:00:00
# DB min: 2024-04-18 12:00:00.081000 max: 2024-05-24 22:59:59.434000
# Case: SL
# Approx Time: 2024-04-25 12:00:00, Price: 1.07216
# Matched Time: 2024-04-25 11:25:00.451000, Price: 1.07216
# Return True: -0.01
# Return: -0.01% | MDD: -0.05% | CALMAR: -0.20 | UI: 0.02 | UPI: -0.40
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-18 14:30:00 to 2024-05-25 14:30:00
# DB min: 2024-04-18 14:30:00.005000 max: 2024-05-24 22:59:59.434000
# Case: PARTIAL
# Approx Time: 2024-04-25 14:30:00, Price: 1.07386
# Matched Time: 2024-04-25 14:30:17.383000, Price: 1.07386
# Return True: 0.03
# Return: 0.00% | MDD: -0.56% | CALMAR: -0.01 | UI: 0.34 | UPI: -0.01
# Return Verification: False
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-16 12:00:00 to 2024-05-23 12:00:00
# DB min: 2024-04-16 12:00:00.064000 max: 2024-05-23 11:59:58.346000
# Case: SL
# Approx Time: 2024-04-23 12:00:00, Price: 1.06747
# Matched Time: 2024-04-23 10:54:13.307000, Price: 1.06746
# Return True: -0.01
# Return: -0.01% | MDD: -0.21% | CALMAR: -0.05 | UI: 0.08 | UPI: -0.13
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-16 11:00:00 to 2024-05-23 11:00:00
# DB min: 2024-04-16 11:00:00.126000 max: 2024-05-23 10:59:59.853000
# Case: TP
# Approx Time: 2024-04-23 11:00:00, Price: 1.06647
# Matched Time: 2024-04-23 11:03:50.379000, Price: 1.06647
# Return True: 0.05
# Return: 0.05% | MDD: -0.11% | CALMAR: 0.35 | UI: 0.05 | UPI: 0.78
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-11 12:10:00 to 2024-05-18 12:10:00
# DB min: 2024-04-11 12:10:00.162000 max: 2024-05-17 22:59:59.180000
# Case: TP
# Approx Time: 2024-04-18 12:10:00, Price: 1.06747
# Matched Time: 2024-04-18 12:04:21.469000, Price: 1.06747
# Return True: 0.00
# Return: nan% | MDD: -0.02% | CALMAR: nan | UI: 0.01 | UPI: nan
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-11 12:03:00 to 2024-05-18 12:03:00
# DB min: 2024-04-11 12:03:00.980000 max: 2024-05-17 22:59:59.180000
# Case: TP
# Approx Time: 2024-04-18 12:03:00, Price: 1.06727
# Matched Time: 2024-04-18 12:02:45.930000, Price: 1.06726
# Return True: 0.00
# Return: nan% | MDD: -0.09% | CALMAR: nan | UI: 0.04 | UPI: nan
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-11 12:02:00 to 2024-05-18 12:02:00
# DB min: 2024-04-11 12:02:09.803000 max: 2024-05-17 22:59:59.180000
# Case: TP
# Approx Time: 2024-04-18 12:02:00, Price: 1.06721
# Matched Time: 2024-04-18 12:02:19.311000, Price: 1.06721
# Return True: 0.00
# Return: nan% | MDD: -0.09% | CALMAR: nan | UI: 0.05 | UPI: nan
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-11 12:01:00 to 2024-05-18 12:01:00
# DB min: 2024-04-11 12:01:03.430000 max: 2024-05-17 22:59:59.180000
# Case: TP
# Approx Time: 2024-04-18 12:01:00, Price: 1.06721
# Matched Time: 2024-04-18 12:02:19.311000, Price: 1.06721
# Return True: 0.00
# Return: nan% | MDD: -0.09% | CALMAR: nan | UI: 0.05 | UPI: nan
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-11 07:40:00 to 2024-05-18 07:40:00
# DB min: 2024-04-11 07:40:06.121000 max: 2024-05-17 22:59:59.180000
# Case: SL
# Approx Time: 2024-04-18 07:40:00, Price: 1.06827
# Matched Time: 2024-04-18 07:44:21.699000, Price: 1.06828
# Return True: -0.01
# Return: -0.01% | MDD: -0.08% | CALMAR: -0.12 | UI: 0.04 | UPI: -0.23
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-04 15:30:00 to 2024-05-11 15:30:00
# DB min: 2024-04-04 15:30:00.128000 max: 2024-05-10 22:59:59.760000
# Case: PARTIAL
# Approx Time: 2024-04-11 15:30:00, Price: 1.07502
# Matched Time: 2024-04-11 15:28:49.098000, Price: 1.07503
# Return True: 0.01
# Return: nan% | MDD: -2.00% | CALMAR: nan | UI: 0.89 | UPI: nan
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-04 19:30:00 to 2024-05-11 19:30:00
# DB min: 2024-04-04 19:30:01.477000 max: 2024-05-10 22:59:59.760000
# Case: PARTIAL
# Approx Time: 2024-04-11 19:30:00, Price: 1.07523
# Matched Time: 2024-04-11 15:31:16.981000, Price: 1.07523
# Return True: 0.01
# Return: 0.00% | MDD: -1.43% | CALMAR: -0.00 | UI: 0.76 | UPI: -0.01
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-03 15:00:00 to 2024-05-10 15:00:00
# DB min: 2024-04-03 15:00:00.062000 max: 2024-05-10 14:59:55.854000
# Case: SL
# Approx Time: 2024-04-10 15:00:00, Price: 1.07626
# Matched Time: 2024-04-10 15:37:56.192000, Price: 1.07626
# Return True: -0.01
# Return: -0.01% | MDD: -0.08% | CALMAR: -0.13 | UI: 0.04 | UPI: -0.25
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-03 14:30:00 to 2024-05-10 14:30:00
# DB min: 2024-04-03 14:30:00.044000 max: 2024-05-10 14:29:54.518000
# Case: PARTIAL
# Approx Time: 2024-04-10 14:30:00, Price: 1.07821
# Matched Time: 2024-04-10 14:38:08.843000, Price: 1.07821
# Return True: 0.01
# Return: nan% | MDD: -0.09% | CALMAR: nan | UI: 0.04 | UPI: nan
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-02 13:00:00 to 2024-05-09 13:00:00
# DB min: 2024-04-02 13:00:00.083000 max: 2024-05-09 12:59:59.713000
# Case: TP
# Approx Time: 2024-04-09 13:00:00, Price: 1.08499
# Matched Time: 2024-04-09 10:06:03.309000, Price: 1.08499
# Return True: 0.04
# Return: 0.04% | MDD: -0.04% | CALMAR: 0.74 | UI: 0.01 | UPI: 2.52
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-04-01 14:00:00 to 2024-05-08 14:00:00
# DB min: 2024-04-01 14:00:00.223000 max: 2024-05-08 13:59:57.615000
# Case: TP
# Approx Time: 2024-04-08 14:00:00, Price: 1.0823
# Matched Time: 2024-04-08 14:00:24.038000, Price: 1.0823
# Return True: 0.05
# Return: 0.05% | MDD: -0.04% | CALMAR: 1.04 | UI: 0.01 | UPI: 2.71
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-03-26 13:00:00 to 2024-05-02 13:00:00
# DB min: 2024-03-26 13:00:00.127000 max: 2024-05-02 12:59:59.602000
# Case: SL
# Approx Time: 2024-04-02 13:00:00, Price: 1.07448
# Matched Time: 2024-04-02 13:00:20.700000, Price: 1.07449
# Return True: -0.01
# Return: -0.01% | MDD: -0.01% | CALMAR: -0.90 | UI: 0.01 | UPI: -1.73
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-03-25 12:00:00 to 2024-05-01 12:00:00
# DB min: 2024-03-25 12:00:00.046000 max: 2024-05-01 11:59:57.099000
# Case: PARTIAL
# Approx Time: 2024-04-01 12:00:00, Price: 1.07762
# Matched Time: 2024-04-01 15:46:55.724000, Price: 1.07762
# Return True: -0.00
# Return: -0.01% | MDD: -0.04% | CALMAR: -0.23 | UI: 0.03 | UPI: -0.32
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-03-19 12:00:00 to 2024-04-26 12:00:00
# DB min: 2024-03-19 12:00:00.077000 max: 2024-04-26 11:59:58.265000
# Case: SL
# Approx Time: 2024-03-26 12:00:00, Price: 1.08487
# Matched Time: 2024-03-26 10:18:22.700000, Price: 1.08487
# Return True: -0.01
# Return: -0.01% | MDD: -0.03% | CALMAR: -0.29 | UI: 0.02 | UPI: -0.42
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-03-18 15:00:00 to 2024-04-25 15:00:00
# DB min: 2024-03-18 15:00:00.024000 max: 2024-04-25 14:59:59.672000
# Case: SL
# Approx Time: 2024-03-25 15:00:00, Price: 1.08074
# Matched Time: 2024-03-25 09:43:34.573000, Price: 1.08074
# Return True: -0.01
# Return: -0.01% | MDD: -0.54% | CALMAR: -0.02 | UI: 0.28 | UPI: -0.04
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-03-18 12:00:00 to 2024-04-25 12:00:00
# DB min: 2024-03-18 12:00:00.279000 max: 2024-04-25 11:59:58.884000
# Case: PARTIAL
# Approx Time: 2024-03-25 12:00:00, Price: 1.08163
# Matched Time: 2024-03-25 10:42:41.420000, Price: 1.08164
# Return True: -0.00
# Return: -0.01% | MDD: -0.49% | CALMAR: -0.02 | UI: 0.26 | UPI: -0.04
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-03-14 18:00:00 to 2024-04-21 18:00:00
# DB min: 2024-03-14 18:00:00.088000 max: 2024-04-19 22:59:59.930000
# Case: TP
# Approx Time: 2024-03-21 18:00:00, Price: 39923.18
# Matched Time: 2024-03-21 08:10:26.552000, Price: 1.09426
# Return True: 0.07
# Return: -0.00% | MDD: 0.00% | CALMAR: nan | UI: 0.00 | UPI: inf
# Return Verification: False
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-03-14 18:00:00 to 2024-04-21 18:00:00
# DB min: 2024-03-14 18:00:00.088000 max: 2024-04-19 22:59:59.930000
# Case: SL
# Approx Time: 2024-03-21 18:00:00, Price: 1.08929
# Matched Time: 2024-03-21 14:47:30.337000, Price: 1.0893
# Return True: -0.01
# Return: -0.01% | MDD: -0.02% | CALMAR: -0.45 | UI: 0.01 | UPI: -1.02
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-03-14 11:00:00 to 2024-04-21 11:00:00
# DB min: 2024-03-14 11:00:02.961000 max: 2024-04-19 22:59:59.930000
# Case: SL
# Approx Time: 2024-03-21 11:00:00, Price: 1.09163
# Matched Time: 2024-03-21 11:03:20.292000, Price: 1.09163
# Return True: -0.00
# Return: -0.01% | MDD: -0.02% | CALMAR: -0.41 | UI: 0.01 | UPI: -0.83
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-03-11 12:00:00 to 2024-04-18 12:00:00
# DB min: 2024-03-11 12:00:00.116000 max: 2024-04-18 11:59:59.423000
# Case: TP
# Approx Time: 2024-03-18 12:00:00, Price: 1.09048
# Matched Time: 2024-03-18 12:33:16.695000, Price: 1.09047
# Return True: 0.03
# Return: nan% | MDD: -0.07% | CALMAR: nan | UI: 0.03 | UPI: nan
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-02-20 10:00:00 to 2024-03-27 10:00:00
# DB min: 2024-02-20 10:00:00.003000 max: 2024-03-27 09:59:59.897000
# Case: SL
# Approx Time: 2024-02-27 10:00:00, Price: 1.08633
# Matched Time: 2024-02-27 09:49:58.188000, Price: 1.08633
# Return True: -0.00
# Return: -0.00% | MDD: -0.65% | CALMAR: -0.01 | UI: 0.31 | UPI: -0.02
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-02-09 05:20:00 to 2024-03-16 05:20:00
# DB min: 2024-02-09 05:20:02.113000 max: 2024-03-15 21:59:59.165000
# Case: PARTIAL
# Approx Time: 2024-02-16 05:20:00, Price: 1.07577
# Matched Time: 2024-02-16 05:21:24.710000, Price: 1.07577
# Return True: 0.00
# Return: 0.08% | MDD: -0.45% | CALMAR: 0.13 | UI: 0.16 | UPI: 0.39
# Return Verification: False
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-02-08 14:30:00 to 2024-03-15 14:30:00
# DB min: 2024-02-08 14:30:00.339000 max: 2024-03-15 14:29:59.717000
# Case: SL
# Approx Time: 2024-02-15 14:30:00, Price: 1.07628
# Matched Time: 2024-02-15 14:30:11.403000, Price: 1.07627
# Return True: -0.02
# Return: -0.02% | MDD: -0.08% | CALMAR: -0.51 | UI: 0.05 | UPI: -0.76
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-02-06 17:40:00 to 2024-03-13 17:40:00
# DB min: 2024-02-06 17:40:00.148000 max: 2024-03-13 17:39:59.559000
# Case: PARTIAL
# Approx Time: 2024-02-13 17:40:00, Price: 1.07136
# Matched Time: 2024-02-13 17:21:19.218000, Price: 1.07136
# Return True: 0.02
# Return: 0.02% | MDD: -0.06% | CALMAR: 0.19 | UI: 0.03 | UPI: 0.34
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-02-06 14:00:00 to 2024-03-13 14:00:00
# DB min: 2024-02-06 14:00:00.152000 max: 2024-03-13 13:59:59.760000
# Case: TP
# Approx Time: 2024-02-13 14:00:00, Price: 1.07958
# Matched Time: 2024-02-13 14:30:01.185000, Price: 1.07957
# Return True: 0.16
# Return: 0.16% | MDD: -0.12% | CALMAR: 1.24 | UI: 0.05 | UPI: 3.00
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-02-02 11:00:00 to 2024-03-09 11:00:00
# DB min: 2024-02-02 11:00:00.219000 max: 2024-03-08 22:59:59.148000
# Case: TP
# Approx Time: 2024-02-09 11:00:00, Price: 1.07847
# Matched Time: 2024-02-09 09:31:24.171000, Price: 1.07847
# Return True: 0.15
# Return: 0.16% | MDD: -0.41% | CALMAR: 0.38 | UI: 0.18 | UPI: 0.85
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-02-01 14:30:00 to 2024-03-08 14:30:00
# DB min: 2024-02-01 14:30:00.171000 max: 2024-03-08 14:29:59.981000
# Case: TP
# Approx Time: 2024-02-08 14:30:00, Price: 1.07438
# Matched Time: 2024-02-08 14:43:53.025000, Price: 1.07438
# Return True: 0.12
# Return: 0.12% | MDD: -0.21% | CALMAR: 0.53 | UI: 0.09 | UPI: 1.25
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-01-26 14:30:00 to 2024-03-02 14:30:00
# DB min: 2024-01-26 14:30:00.053000 max: 2024-03-01 22:59:59.169000
# Case: SL
# Approx Time: 2024-02-02 14:30:00, Price: 1.08179
# Matched Time: 2024-02-02 14:35:43.326000, Price: 1.08179
# Return True: -0.02
# Return: -0.02% | MDD: -0.16% | CALMAR: -0.24 | UI: 0.05 | UPI: -0.75
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-01-25 14:15:00 to 2024-03-01 14:15:00
# DB min: 2024-01-25 14:15:00.829000 max: 2024-03-01 14:14:57.762000
# Case: SL
# Approx Time: 2024-02-01 14:15:00, Price: 1.08543
# Matched Time: 2024-02-01 17:38:16.725000, Price: 1.08543
# Return True: -0.02
# Return: -0.02% | MDD: -0.06% | CALMAR: -0.65 | UI: 0.03 | UPI: -1.29
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-01-12 14:19:00 to 2024-02-19 14:19:00
# DB min: 2024-01-12 14:19:00.128000 max: 2024-02-19 14:18:58.029000
# Case: PARTIAL
# Approx Time: 2024-01-19 14:19:00, Price: 1.0888
# Matched Time: 2024-01-19 14:19:01.873000, Price: 1.0888
# Return True: 0.02
# Return: 0.00% | MDD: -0.06% | CALMAR: -0.16 | UI: 0.02 | UPI: -0.48
# Return Verification: False
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2024-01-12 14:05:00 to 2024-02-19 14:05:00
# DB min: 2024-01-12 14:05:00.152000 max: 2024-02-19 14:04:59.814000
# Case: TP
# Approx Time: 2024-01-19 14:05:00, Price: 1.08807
# Matched Time: 2024-01-19 13:55:16.458000, Price: 1.08808
# Return True: 0.09
# Return: 0.08% | MDD: -0.05% | CALMAR: 1.34 | UI: 0.02 | UPI: 3.39
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-10-24 09:58:05 to 2023-11-30 09:58:05
# DB min: 2023-10-24 09:58:06.795000 max: 2023-11-30 09:58:03.086000
# Case: PARTIAL
# Approx Time: 2023-10-31 09:58:05, Price: 1.06643
# Matched Time: 2023-10-31 10:58:05.302000, Price: 1.06643
# Return True: 0.13
# Return: 0.00% | MDD: -0.11% | CALMAR: -0.29 | UI: 0.05 | UPI: -0.67
# Return Verification: False
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-10-16 19:00:00 to 2023-11-23 19:00:00
# DB min: 2023-10-16 19:00:03.551000 max: 2023-11-23 18:59:59.930000
# Case: SL
# Approx Time: 2023-10-23 19:00:00, Price: 1.0658
# Matched Time: 2023-10-23 18:54:39.923000, Price: 1.06581
# Return True: -0.02
# Return: -0.02% | MDD: -0.09% | CALMAR: -0.47 | UI: 0.05 | UPI: -0.79
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-10-09 12:00:00 to 2023-11-16 12:00:00
# DB min: 2023-10-09 12:00:00.167000 max: 2023-11-16 11:59:58.353000
# Case: PARTIAL
# Approx Time: 2023-10-16 12:00:00, Price: 1.05319
# Matched Time: 2023-10-16 12:00:00.196000, Price: 1.0532
# Return True: 0.02
# Return: 0.02% | MDD: -0.08% | CALMAR: 0.07 | UI: 0.03 | UPI: 0.19
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-09-27 13:01:00 to 2023-11-04 13:01:00
# DB min: 2023-09-27 13:01:05.603000 max: 2023-11-03 21:59:59.055000
# Case: PARTIAL
# Approx Time: 2023-10-04 13:01:00, Price: 1.0509
# Matched Time: 2023-10-04 13:05:18.132000, Price: 1.0509
# Return True: 0.00
# Return: 0.00% | MDD: -0.08% | CALMAR: -0.03 | UI: 0.06 | UPI: -0.04
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-09-27 13:00:00 to 2023-11-04 13:00:00
# DB min: 2023-09-27 13:00:00.298000 max: 2023-11-03 21:59:59.055000
# Case: PARTIAL
# Approx Time: 2023-10-04 13:00:00, Price: 1.05061
# Matched Time: 2023-10-04 13:02:24.372000, Price: 1.05061
# Return True: 0.00
# Return: 0.00% | MDD: -0.11% | CALMAR: -0.09 | UI: 0.06 | UPI: -0.17
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-09-14 16:40:00 to 2023-10-21 16:40:00
# DB min: 2023-09-14 16:40:00.177000 max: 2023-10-20 22:59:59.306000
# Case: TP
# Approx Time: 2023-09-21 16:40:00, Price: 1.06324
# Matched Time: 2023-09-21 14:40:21.426000, Price: 1.06324
# Return True: 0.09
# Return: 0.09% | MDD: -0.22% | CALMAR: 0.37 | UI: 0.09 | UPI: 0.93
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-09-13 15:00:00 to 2023-10-20 15:00:00
# DB min: 2023-09-13 15:00:00.130000 max: 2023-10-20 14:59:59.937000
# Case: SL
# Approx Time: 2023-09-20 15:00:00, Price: 1.07078
# Matched Time: 2023-09-20 15:12:39.589000, Price: 1.07078
# Return True: -0.01
# Return: -0.01% | MDD: -0.09% | CALMAR: -0.22 | UI: 0.04 | UPI: -0.52
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-09-05 18:00:00 to 2023-10-12 18:00:00
# DB min: 2023-09-05 18:00:00.085000 max: 2023-10-12 17:59:59.852000
# Case: PARTIAL
# Approx Time: 2023-09-12 18:00:00, Price: 1.07358
# Matched Time: 2023-09-12 18:17:01.249000, Price: 1.07358
# Return True: -0.00
# Return: -0.01% | MDD: -0.40% | CALMAR: -0.04 | UI: 0.25 | UPI: -0.06
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-08-23 15:00:00 to 2023-09-30 15:00:00
# DB min: 2023-08-23 15:00:00.024000 max: 2023-09-29 22:59:56.147000
# Case: SL
# Approx Time: 2023-08-30 15:00:00, Price: 1.09235
# Matched Time: 2023-08-30 14:59:28.238000, Price: 1.09234
# Return True: -0.01
# Return: -0.01% | MDD: -0.11% | CALMAR: -0.18 | UI: 0.04 | UPI: -0.45
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-08-18 17:00:00 to 2023-09-25 17:00:00
# DB min: 2023-08-18 17:00:00.114000 max: 2023-09-25 16:59:59.351000
# Case: PARTIAL
# Approx Time: 2023-08-25 17:00:00, Price: 1.07739
# Matched Time: 2023-08-25 17:00:29.614000, Price: 1.0774
# Return True: 0.18
# Return: 0.18% | MDD: -0.15% | CALMAR: 0.71 | UI: 0.04 | UPI: 2.46
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*
# Filter range: 2023-08-18 16:00:00 to 2023-09-25 16:00:00
# DB min: 2023-08-18 16:00:00.099000 max: 2023-09-25 15:59:59.664000
# Case: TP
# Approx Time: 2023-08-25 16:00:00, Price: 1.0771
# Matched Time: 2023-08-25 16:53:51.677000, Price: 1.07709
# Return True: 0.14
# Return: 0.15% | MDD: -0.15% | CALMAR: 0.94 | UI: 0.04 | UPI: 3.13
# Return Verification: True
# *~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~*

# %%
df
# Out:
#                     Entry_Time                 Entry_Price  \
# 0   2025-02-27 10:12:13.086000  2025-02-27 10:12:13.086000
# 1   2025-02-26 12:21:01.297000  2025-02-26 12:21:01.297000
# 2   2025-02-24 19:27:29.154000  2025-02-24 19:27:29.154000
# 3   2025-02-18 13:07:12.323000  2025-02-18 13:07:12.323000
# 4   2025-02-17 16:52:34.842000  2025-02-17 16:52:34.842000
# ..                         ...                         ...
# 64  2023-09-20 15:12:39.589000  2023-09-20 15:12:39.589000
# 65  2023-09-12 18:17:01.249000  2023-09-12 18:17:01.249000
# 66  2023-08-30 14:59:28.238000  2023-08-30 14:59:28.238000
# 67  2023-08-25 17:00:29.614000  2023-08-25 17:00:29.614000
# 68  2023-08-25 16:53:51.677000  2023-08-25 16:53:51.677000
#
#                      Exit_Time                  Exit_Price       TP       SL  \
# 0   2025-02-27 10:19:27.193000  2025-02-27 10:12:13.086000  1.04705  1.04811
# 1   2025-02-26 12:33:21.590000  2025-02-26 12:21:01.297000  1.04799  1.04965
# 2   2025-02-25 21:29:10.830000  2025-02-24 19:27:29.154000  1.04494  1.05287
# 3   2025-02-20 16:29:55.853000  2025-02-18 13:07:12.323000  1.04574  1.04672
# 4   2025-02-17 22:38:28.854000  2025-02-17 16:52:34.842000  1.04848  1.04766
# ..                         ...                         ...      ...      ...
# 64  2023-09-20 15:43:32.133000  2023-09-20 15:12:39.589000  1.06319  1.07133
# 65  2023-09-13 08:05:09.002000  2023-09-12 18:17:01.249000  1.07104  1.07391
# 66  2023-08-30 15:15:49.386000  2023-08-30 14:59:28.238000  1.09058  1.09257
# 67  2023-08-25 19:02:47.160000  2023-08-25 17:00:29.614000  1.08415  1.07645
# 68  2023-08-25 20:22:25.541000  2023-08-25 16:53:51.677000  1.08101  1.07683
#
#       Risk    State    Return       MDD    CALMAR        UI       UPI
# 0   0.0100  PARTIAL  0.000000 -0.033400 -0.299400  0.019155 -0.522063
# 1   0.0010  PARTIAL  0.000042 -0.036219 -0.026459  0.014902 -0.064310
# 2   0.0100  PARTIAL -0.007448 -0.602490 -0.028959  0.306851 -0.056861
# 3   0.0100  PARTIAL  0.000000 -0.625889 -0.015977  0.244832 -0.040844
# 4   0.0020       TP  0.018750 -0.056282  0.297611  0.027427  0.610720
# ..     ...      ...       ...       ...       ...       ...       ...
# 64  0.0100       SL -0.010182 -0.093428 -0.216014  0.038818 -0.519904
# 65  0.0075  PARTIAL -0.007500 -0.404783 -0.037057  0.245386 -0.061128
# 66  0.0100       SL -0.010000 -0.113623 -0.176021  0.044708 -0.447350
# 67  0.0700  PARTIAL  0.176105 -0.150216  0.706353  0.043119  2.460770
# 68  0.0100       TP  0.150769 -0.150216  0.937115  0.044929  3.133150
#
# [69 rows x 13 columns]

# %% [markdown]
# 69 trades
# 130 true
# 130 – 69 =  61
#
# 8 False for Return verification = 11%

# %%
print((1 + df['Return']).cumprod() - 1)
# Out:
# 0     0.000000
# 1     0.000042
# 2    -0.007406
# 3    -0.007406
# 4     0.011205
#         ...
# 64    1.870863
# 65    1.849331
# 66    1.820838
# 67    2.317602
# 68    2.817795
# Name: Return, Length: 69, dtype: float64
